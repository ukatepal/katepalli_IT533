# %% [markdown]
# <a href="https://colab.research.google.com/github/ukatepal/katepalli_IT533/blob/main/week3lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
kickstarter = pd.read_csv("https://raw.githubusercontent.com/ukatepal/katepalli-kickstartIT603/main/kickstarter-projects-201518.csv",encoding="ISO-8859-1")
kickstarter.dropna(inplace=True)

# %%
k = kickstarter
k
# Out:
#                 ID                                               name  \
# 0       1008941852                       The return of BABY UNIVERSE!
# 1       1013503401                                             Potjie
# 2       1020446396  Stilt City- A Bungalow Artist Space in The Roc...
# 3       1028008131       A 2D SideScroller RPG Made by YOU (Canceled)
# 4       1049544313                                       Balteus Belt
# ...            ...                                                ...
# 191580    55596200                         Plateforme de statistiques
# 191581   872683023  The Lewisham Ledger - a new free local communi...
# 191582  1036415983                                      Aikyam : Onnu
# 191583  1916988520                          Back in Black Hills Movie
# 191584    22387366                                       Nerd Collect
#
#            category main_category currency  deadline    goal  \
# 0         Immersive       Theater      USD  1/1/2015   15000
# ...

# %% [markdown]
# 1. Data Transformation: Pick three variables whose data types may be more useful as another data
# type and utransform them to numeric or character/ categorical format. Then, insert a text section
# into your notebook and explain in no less than 3 sentences what this transformation will allow you
# to accomplish analytically later on.

# %%
# First Variable: state
# First, we back the dataframe up.
k1=kickstarter

# %%
# Now we build the column and copy the original values into it
k1['state_num'] = k1.state

# %%
# Third, we convert state_num into categorical
k1['state_num']= k1['state_num'].astype('category')

# %%
# Then, we replace the strings with the category indices
k1['state_num']= k1['state_num'].cat.codes

# %%
# Now, we check the data types
k1.dtypes[['state','state_num']]
#k1.state_num.iloc[20:25]
# Out:
# state        object
# state_num      int8
# dtype: object

# %%
# First, we back the dataframe up.
k1=kickstarter
# Now we build the column and copy the original values into it
k1['category_num'] = k1.state
# Third, we convert category_num into categorical
k1['category_num']= k1['category_num'].astype('category')
# Then, we replace the strings with the category indices
k1['category_num']= k1['category_num'].cat.codes
# Now, we check the data types
k1.dtypes[['category','category_num']]
#k1[['category', 'category_num']].iloc[20:25]
#k1.category_num.iloc[20:25]
# Out:
# category        object
# category_num      int8
# dtype: object

# %%
# First, we back the dataframe up.
k1=kickstarter
# Now we build the column and copy the original values into it
k1[
'pledged_int'
] = k1.pledged
# Third, we convert pledged_num into int32
k1[
'pledged_int'
]= k1[
'pledged_int'
].astype(
'int32'
)
# Then, we replace the strings with the category indices
#k1['category_num']= k1['category_num'].cat.codes
# Now, we check the data types
k1.dtypes[[
'pledged'
,
'pledged_int'
]]

k1.head()
# Out:
#            ID                                               name     category  \
# 0  1008941852                       The return of BABY UNIVERSE!    Immersive
# 1  1013503401                                             Potjie        Drama
# 2  1020446396  Stilt City- A Bungalow Artist Space in The Roc...   Public Art
# 3  1028008131       A 2D SideScroller RPG Made by YOU (Canceled)  Video Games
# 4  1049544313                                       Balteus Belt      Apparel
#
#   main_category currency  deadline   goal          launched   pledged  \
# 0       Theater      USD  1/1/2015  15000   12/4/2014 21:37  11880.18
# 1  Film & Video      GBP  1/1/2015   4500   12/2/2014 18:10   4843.00
# 2           Art      USD  1/1/2015  60000  11/19/2014 23:14  18087.00
# 3         Games      USD  1/1/2015  20000   12/2/2014 22:02      9.00
# 4       Fashion      USD  1/1/2015   8000  11/18/2014 21:17   1563.00
#
# ...

# %% [markdown]
# Here Data transformation makes kickstarter data set to transform and assign categorical and int62values to the values of state, category and pledged varaibles.
# It enabled us to categorize given raw data set into usable format that is here after datatransformation we can perform seperate operations and analyze data in own perspectives.Transformed data may be easier for both humans and computers to use.
# It improves data quality and protects applications from potential landmines such as null values,unexpected duplicates, incorrect indexing, and incompatible formats.

# %% [markdown]
# 2. Data Substitution: Substitute values in at least two variables. Insert a text section into yournotebook and explain in no less than 3 sentences how you decided what values to use forsubstitution and, in addition to your explanation, show your code.

# %%
#variable 1: main_category-Technology
k2 = kickstarter
k2.main_category.unique()
#k2['currency'].isnull().values.any()
# Out:
# array(['Theater', 'Film & Video', 'Art', 'Games', 'Fashion', 'Publishing',
#        'Technology', 'Food', 'Music', 'Design', 'Crafts', 'Journalism',
#        'Dance', 'Comics', 'Photography'], dtype=object)

# %%
# Instead of building another column to see any transformations, we will substitute da
# For this purpose, we're using the replace() method from pandas
k2.main_category.replace(
'Technology'
,
'Automation'
, inplace=
True
)
# Did we indeed replace all '?'? Let's check:
k2[k2['main_category'] =='Technology']
# Out:
# Empty DataFrame
# Columns: [ID, name, category, main_category, currency, deadline, goal, launched, pledged, state, backers, country, usd pledged, usd_pledged_real, usd_goal_real, state_num, category_num, pledged_int]
# Index: []

# %%
k2.main_category.unique()
# Out:
# array(['Theater', 'Film & Video', 'Art', 'Games', 'Fashion', 'Publishing',
#        'Automation', 'Food', 'Music', 'Design', 'Crafts', 'Journalism',
#        'Dance', 'Comics', 'Photography'], dtype=object)

# %%
#Variable 2: "state-canceled"
k2.state.unique()
# Out:
# array(['failed', 'successful', 'canceled', 'suspended', 'live'],
#       dtype=object)

# %%
k2.state.replace(
'canceled'
,
'cancelled'
, inplace=
True
)
k2.state.unique()
# Out:
# array(['failed', 'successful', 'cancelled', 'suspended', 'live'],
#       dtype=object)

# %% [markdown]
# 1.
# I choose 'canceled' value in "state" variable and replaced "cancelled" value at canceled as it ismisspelled.
# 2.
# And I choose Technology value in main_category and replaced with "Automation" value atTechnology as to improve the technical name.
# 3.
# Through the data substitution we can replace all data in raw data set as per requirements ifany of the raw data is mistaken or need to be improved.

# %% [markdown]
# 3. Data Reduction: Pick two variables that could be simplifi ed by binning or bucketing, or bynormalization or standardization. Then perform the operation(s) you have chosen. Insert a textsection into your notebook and explain in no less than 3 sentences what benefi t this may providefor any later analysis.

# %%
kickstarter.backers.describe()
# Out:
# count    188445.000000
# mean        114.758704
# std        1026.348301
# min           0.000000
# 25%           1.000000
# 50%           8.000000
# 75%          51.000000
# max      219382.000000
# Name: backers, dtype: float64

# %%
bins = np.linspace(kickstarter.backers.
min
(),kickstarter.backers.
max
(),
7
)
bins
# Out:
# array([     0.        ,  36563.66666667,  73127.33333333, 109691.        ,
#        146254.66666667, 182818.33333333, 219382.        ])

# %%
labels = [
'very_low'
,
'low'
,
'medium'
,
'Moderate_high'
,
'high'
,
'very_high'
]

# %%
# Variable 1: backers simplified by using Binning methods.
k3 = kickstarter
k3[
'bins'
] = pd.cut(k3[
'backers'
], bins=bins, labels=labels, include_lowest=
True
)
k3[k3.backers>=
40000
]
# Out:
#                 ID                                               name  \
# 8041    1955357092                                  Exploding Kittens
# 17283   1799979574   Pebble Time - Awesome Smartwatch, No Compromises
# 36952   1074800880                  Bloodstained: Ritual of the Night
# 37846   1194278206         Yooka-Laylee - A 3D Platformer Rare-vival!
# 45185    947809001                                          Shenmue 3
# 50737   2095857140  ZNAPS -The $9 Magnetic Adapter for your mobile...
# 54622    565687737  The World's Best TRAVEL JACKET with 15 Feature...
# 59593    275698538                           Divinity: Original Sin 2
# 66194    474183945                                         BATTLETECH
# 73934   1454565733            Bring Back MYSTERY SCIENCE THEATER 3000
# 88075   1494516688                                      Joking Hazard
# 107972  2103598555             Pebble 2, Time 2 + All-New Pebble Core
# ...

# %%
k3.groupby([
'bins'
]).count()
# Out:
#                    ID    name  category  main_category  currency  deadline  \
# bins
# very_low       188426  188426    188426         188426    188426    188426
# low                14      14        14             14        14        14
# medium              3       3         3              3         3         3
# Moderate_high       0       0         0              0         0         0
# high                1       1         1              1         1         1
# very_high           1       1         1              1         1         1
#
#                  goal  launched  pledged   state  backers  country  \
# bins
# very_low       188426    188426   188426  188426   188426   188426
# low                14        14       14      14       14       14
# medium              3         3        3       3        3        3
# Moderate_high       0         0        0       0        0        0
# high                1         1        1       1        1        1
# ...

# %%
kickstarter.usd_goal_real.describe()
# Out:
# count    1.884450e+05
# mean     6.120491e+04
# std      1.425486e+06
# min      4.900000e-01
# 25%      2.000000e+03
# 50%      6.500000e+03
# 75%      2.000000e+04
# max      1.513959e+08
# Name: usd_goal_real, dtype: float64

# %%
# Variable 2: usd_goal_real simplified by using Bucketing method.
# Setting up our 5 buckets and their labels
buckets = [0, 30279173.98, 60558347.96, 90837521.94, 121116695.9, 151395869.9]
bucketlabels = ['very_low', 'low', 'middle', 'high', 'super-high']

# Using cut() to separate data into the buckets we have built
k3['buckets'] = pd.cut(k3['usd_goal_real'] , bins=buckets, labels=bucketlabels, include_lowest=True)

# Check if we have the new attribute 'buckets' at the end of our dataset
k3[k3.usd_goal_real>=70000000]
# Out:
#                 ID                                               name  \
# 10619    601594365      The Multi-Trillion Dollar Dreamâ¢ (Canceled)
# 11027    388031956                                       UniqueTrends
# 21440    962949560                 "PG" Reanimated Cartoons Tha Movie
# 27372    308045282                                       Jesus Priest
# 32610   1746196981                               High Gear (Canceled)
# 40402   2075450016          Virtual Reality Playground in Buffalo, NY
# 40740   1720842777                                  NAKED FASHION ART
# 40765   1933151256  404 ERROR - The first emergency kit for an int...
# 46932    492821983  Back to the future! Hill Valley winnemucca, Ne...
# 48109   2094346154                              Is Anyone Out There ?
# 52308    499583381                    The Scariest Movie Ever Created
# 60763    219702078                Kitchen from Austria in Switzerland
# ...

# %%
k3.groupby(['buckets']).count()
# Out:
#                 ID    name  category  main_category  currency  deadline  \
# buckets
# very_low    188390  188390    188390         188390    188390    188390
# low             25      25        25             25        25        25
# middle           6       6         6              6         6         6
# high            23      23        23             23        23        23
# super-high       1       1         1              1         1         1
#
#               goal  launched  pledged   state  backers  country  usd pledged  \
# buckets
# very_low    188390    188390   188390  188390   188390   188390       188390
# low             25        25       25      25       25       25           25
# middle           6         6        6       6        6        6            6
# high            23        23       23      23       23       23           23
# super-high       1         1        1       1        1        1            1
#
# ...

# %% [markdown]
# 1.
# I have choosen backers variable values to reduce using binning method because backers datain this data set is used for us to know how many backers for the each ID and categorizing it interms of range is useful to know which range does it fall.
# 2.
# I have choosen usd_goal_real variable values to reduce using bucketing method because ifusd_goal_real categorizing it in terms of range is useful to know which range does it fall toanalyze how profi ts we get.
# 3.
# I choose binning method for backers data because backers data should distibute into equallyand used bucketing method for usd_real_goal as there is no necessary to distribue estimatedprofi t equally.
# *
# 4. Now that you have a better dataset, think about any important organizational analytical questionsthat management could ask about the dataset in order to help them make business or organizationaldecisions. *
# What can we analysis with the data bins of backers in data set and how can we use that data toimprove business?
